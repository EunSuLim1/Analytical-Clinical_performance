# %%
import pandas as pd
import seaborn as sns
a = [667.30,408.90,159.00,5014.20,1533.10,764.60,1062.70,514.00,202.20,2079.90,627.60,1285.70,135.80,509.00,776.00,769.20,516.50,345.70,1304.00,1790.90]
p = [348.7609218,251.9386359,113.4674031,1351.438519,1324.18539,363.8592393,829.4885128,335.1720955,131.4484069,1168.968996,317.969298,1378.545522,98.64078971,251.1763195,385.2792823,308.7449427,182.1180974,145.0570087,654.6058014,1459.092463]
a_p = pd.DataFrame({'abbott': a,'pcl':p})
a_p
sns.lmplot(x="abbott", y="pcl", data=a_p,
           robust=True, ci=None, scatter_kws={"s": 80});

# %%
sns.lmplot(x="abbott", y="pcl", data=a_p, ci=None, scatter_kws={"s": 80});
