# %%
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import scipy.stats as stats
import random
import numpy as np
import math

# %%
# df1 = pd.read_excel("내 PC/cloudium 서버 (U:)/PCLOK II/00. 연구원 개인폴더/임은수/LOB,D_Raw.xlsx")
# print(df1.shape)
# df1.head(10)

# %%
blank_random = [random.random() for i in range(1,61)]
rep = [i for i in range(1,61)]
df2 = pd.DataFrame({'rep': rep, 'Blank' : blank_random})
df2
# Out:
#     rep     Blank
# 0     1  0.417254
# 1     2  0.883088
# 2     3  0.890366
# 3     4  0.588908
# 4     5  0.138001
# 5     6  0.645257
# 6     7  0.322176
# 7     8  0.189878
# 8     9  0.518954
# 9    10  0.422655
# 10   11  0.126570
# 11   12  0.737905
# 12   13  0.724619
# 13   14  0.711754
# 14   15  0.866703
# 15   16  0.535627
# 16   17  0.895597
# 17   18  0.453191
# 18   19  0.167057
# 19   20  0.179740
# 20   21  0.752829
# 21   22  0.140601
# 22   23  0.945695
# 23   24  0.431669
# 24   25  0.122386
# 25   26  0.455607
# 26   27  0.201668
# 27   28  0.698254
# 28   29  0.021605
# 29   30  0.214145
# 30   31  0.777685
# 31   32  0.748252
# 32   33  0.385397
# 33   34  0.060051
# 34   35  0.873367
# 35   36  0.963263
# 36   37  0.472286
# 37   38  0.175296
# 38   39  0.067355
# 39   40  0.212313
# 40   41  0.663241
# 41   42  0.537266
# 42   43  0.885088
# 43   44  0.713368
# 44   45  0.426364
# 45   46  0.808874
# 46   47  0.291365
# 47   48  0.240664
# 48   49  0.764127
# 49   50  0.262485
# 50   51  0.728684
# 51   52  0.150573
# 52   53  0.394403
# 53   54  0.040167
# 54   55  0.229618
# 55   56  0.327751
# 56   57  0.434634
# 57   58  0.764404
# 58   59  0.526624
# 59   60  0.938724

# %%
# df2=df1.rename(columns={'Unnamed: 1' : 'rep'}).drop(columns=['Unnamed: 0']).set_index('rep')

# %%
sns.histplot(data=df2, x='Blank', kde = True)
# Out:
# <AxesSubplot:xlabel='Blank', ylabel='Count'>

# %%
# 정규성 검정, 귀무가설: 정규성이다. 대립가설: 정규성 아니다.
p_val=stats.normaltest(df2['Blank'])[1]
# p_val

# %%
# print(len(df2['rep']))
# print(np.mean(df2['Blank']))
# print(np.std(df2['Blank']))

# %%
df3 = df2.sort_values(by= 'Blank').reset_index()
df3.index
# Out:
# RangeIndex(start=0, stop=60, step=1)

# %% [markdown]
# ### LOB
#  1. two reagent lot
#  2. one instrument system
#  3. Tree days
#  4. Four blank sample -> LOB
#  5. Four low measurand sample (positive) -> LOD
#  6. Two replicates per sample
#  7. 60 total blank (low sample) replicates per reagent ,

# %% [markdown]
# #### 실수에서 정수부분 소수 부분 분리하는 함수 marh.modf
# a = 1.2345
# math.modf(a)[0]

# %%
df3['rank_position'] = df3['Blank'].rank(method='dense')
df3
df4=df3[['Blank', 'rank_position']].loc[(df3['rank_position'] == 30)]
df3['rank_position'].tolist()[0]
df3
df4
# Out:
#        Blank  rank_position
# 29  0.453191           30.0

# %%
df4=df3['rank_position'] = df3['Blank'].rank(method='dense')
df4
# Out:
# 0      1.0
# 1      2.0
# 2      3.0
# 3      4.0
# 4      5.0
# 5      6.0
# 6      7.0
# 7      8.0
# 8      9.0
# 9     10.0
# 10    11.0
# 11    12.0
# 12    13.0
# 13    14.0
# 14    15.0
# 15    16.0
# 16    17.0
# 17    18.0
# 18    19.0
# 19    20.0
# 20    21.0
# 21    22.0
# 22    23.0
# 23    24.0
# 24    25.0
# 25    26.0
# 26    27.0
# 27    28.0
# 28    29.0
# 29    30.0
# 30    31.0
# 31    32.0
# 32    33.0
# 33    34.0
# 34    35.0
# 35    36.0
# 36    37.0
# 37    38.0
# 38    39.0
# 39    40.0
# 40    41.0
# 41    42.0
# 42    43.0
# 43    44.0
# 44    45.0
# 45    46.0
# 46    47.0
# 47    48.0
# 48    49.0
# 49    50.0
# 50    51.0
# 51    52.0
# 52    53.0
# 53    54.0
# 54    55.0
# 55    56.0
# 56    57.0
# 57    58.0
# 58    59.0
# 59    60.0
# Name: Blank, dtype: float64

# %%
print(df3['Blank'].mean())
print(df3['Blank'].var())
# Out:
# 0.48772411869855836
# 0.08089046721595994

# %%
# LOB ,a=bate = type

B = len(df2['rep']) # Total result of blank samples

if p_val <= 0.05:
    R_P =  (0.5+B*0.95)   
    if type(R_P) == float:
        df3['rank_position'] = df3['Blank'].rank(method='dense')
        f=math.modf(R_P)[0]
        n=math.modf(R_P)[1]
        LoB_non = df3['Blank'][n-1]+f*(df3['Blank'][n-1]-df3['Blank'][n-2])
        print(LoB_non)
    elif:
        LoB_para = B.mean() + B.stdev()
#         df4=df3[['Blank', 'rank_position']].loc[(df3['rank_position'] == round(rank_LoB))]
#         result = df4['rank_position'].tolist()[0]
#         print(df4)
        print(result)
# Out:
#       Blank  rank_position
# 0  0.021605            1.0
# 1.0

# %%
a= 1.111
type(a)
